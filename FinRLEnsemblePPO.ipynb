# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
#import condacolab
#condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
#!pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: wrds in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (3.2.0)
# Requirement already satisfied: numpy<1.27,>=1.26 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from wrds) (1.26.4)
# Requirement already satisfied: packaging<23.3 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from wrds) (23.2)
# Requirement already satisfied: pandas<2.3,>=2.2 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from wrds) (2.2.2)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from wrds) (2.9.9)
# Requirement already satisfied: scipy<1.13,>=1.12 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from wrds) (1.12.0)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from wrds) (2.0.29)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from pandas<2.3,>=2.2->wrds) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from pandas<2.3,>=2.2->wrds) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from pandas<2.3,>=2.2->wrds) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from sqlalchemy<2.1,>=2->wrds) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from sqlalchemy<2.1,>=2->wrds) (3.0.3)
# Requirement already satisfied: six>=1.5 in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.16.0)
# Requirement already satisfied: swig in /home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages (4.2.1)
# E: Could not open lock file /var/lib/apt/lists/lock - open (13: Permission denied)
# E: Unable to lock directory /var/lib/apt/lists/
# W: Problem unlinking the file /var/cache/apt/pkgcache.bin - RemoveCaches (13: Permission denied)
# W: Problem unlinking the file /var/cache/apt/srcpkgcache.bin - RemoveCaches (13: Permission denied)

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent, DRLEnsembleAgentPPO
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# 2024-04-28 00:31:15.314107: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-28 00:31:15.345481: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-28 00:31:15.866472: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
DOW_5_TICKER = [
    "AXP",
    "AMGN",
    "AAPL",
    "BA",
    "CAT",
]
INDEX_5_TICKER = [
    "^DJI", 
    "^IXIC", 
    "^NYA", 
    "^RUT", 
    "^GSPC"
]

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
################################################################################################


# # TRAIN_START_DATE = '2009-04-01'
# # TRAIN_END_DATE = '2021-01-01'
# # TEST_START_DATE = '2021-01-01'
# # TEST_END_DATE = '2022-06-01'


# TRAIN_START_DATE = '2009-06-01'
# #TRAIN_START_DATE = '2010-01-01'
# TRAIN_END_DATE = '2021-10-01'
# TEST_START_DATE = '2021-10-01'
# TEST_END_DATE = '2023-03-01'

# dfexport = YahooDownloader(start_date = TRAIN_START_DATE,
#                      end_date = TEST_END_DATE,
#                      ticker_list = DOW_30_TICKER).fetch_data()


##################################################################################################

# %%
# print(dfexport.shape)

# %%
# #Data export
# import pickle
# datasetName = "dailydata"
# datasetDir = "./datasets"

# os.makedirs(datasetDir, exist_ok=True)
# datasetPath = os.path.join(datasetDir, datasetName) + ".pkl"


# with open(datasetPath, 'wb') as file:
#     pickle.dump(dfexport, file)

# %%
# TRAIN_START_DATE = '2009-04-01'
# TRAIN_END_DATE = '2021-01-01'
# TEST_START_DATE = '2021-01-01'
# TEST_END_DATE = '2022-06-01'
#TRAIN_START_DATE = '2000-01-01'
# TRAIN_START_DATE = '2010-01-01'
# TRAIN_END_DATE = '2021-10-01'
# TEST_START_DATE = '2021-10-01'
# TEST_END_DATE = '2023-03-01'
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2017-10-01'
TEST_START_DATE = '2017-10-01'
TEST_END_DATE = '2023-03-01'


df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = INDEX_5_TICKER).fetch_data()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File tzconversion.pyx:83, in pandas._libs.tslibs.tzconversion.Localizer.__cinit__()
#
# File timezones.pyx:81, in pandas._libs.tslibs.timezones.is_utc()
#
# File timezones.pyx:70, in pandas._libs.tslibs.timezones.is_utc_zoneinfo()
#
# File ~/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages/pandas/compat/_optional.py:150, in import_optional_dependency(name, extra, errors, min_version)
#     148 minimum_version = min_version if min_version is not None else VERSIONS.get(parent)
#     149 if minimum_version:
# --> 150     version = get_version(module_to_get)
#     151     if version and Version(version) < Version(minimum_version):
#     152         msg = (
#     153             f"Pandas requires version '{minimum_version}' or newer of '{parent}' "
#     154             f"(version '{version}' currently installed)."
#     155         )
#
# File ~/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages/pandas/compat/_optional.py:78, in get_version(module)
#      75 version = getattr(module, "__version__", None)
#      77 if version is None:
# ---> 78     raise ImportError(f"Can't determine version for {module.__name__}")
#      79 if module.__name__ == "psycopg2":
#      80     # psycopg2 appends " (dt dec pq3 ext lo64)" to it's version
#      81     version = version.split()[0]
#
# ImportError: Can't determine version for tzdata
# Exception ignored in: 'pandas._libs.tslibs.conversion._localize_tso'
# Traceback (most recent call last):
#   File "tzconversion.pyx", line 83, in pandas._libs.tslibs.tzconversion.Localizer.__cinit__
#   File "timezones.pyx", line 81, in pandas._libs.tslibs.timezones.is_utc
#   File "timezones.pyx", line 70, in pandas._libs.tslibs.timezones.is_utc_zoneinfo
#   File "/home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages/pandas/compat/_optional.py", line 150, in import_optional_dependency
#     version = get_version(module_to_get)
#   File "/home/drew/anaconda3/envs/FinRL_2020v2/lib/python3.9/site-packages/pandas/compat/_optional.py", line 78, in get_version
#     raise ImportError(f"Can't determine version for {module.__name__}")
# ImportError: Can't determine version for tzdata
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (16555, 8)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
# #Andrew Martin - UNCOMMENT BELOW TO ADD PREDICTION INDICATOR
# import pickle
# with open("./datasets/index_5_predictor_2.pkl", 'rb') as file:
#   df_prob = pickle.load(file)
# df6 = df_prob.copy()
# df6 = df6.loc[:, ~df6.columns.duplicated(keep='first')]
# df6["date"] = df6["date"].dt.strftime('%Y-%m-%d')
# df2 = processed.merge(df6[['tic', 'date', 'Predicted_Target']], on=['tic', 'date'], how='left')
# processed = df2.copy()
# INDICATORS.append("Predicted_Target")

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 5, State Space: 51

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgentPPO(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
#from torch.utils.tensorboard import SummaryWriter

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2017-10-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_126_18
# ======A2C Validation from:  2017-10-02 to  2018-01-02
# A2C Sharpe Ratio:  0.07884404695206203
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_126_17
# -----------------------------------
# | time/              |            |
# |    fps             | 420        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -0.1912906 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006669104 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | -0.0256     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.27        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00383    |
# |    reward               | 0.8100672   |
# |    std                  | 1           |
# |    value_loss           | 4.63        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007647055 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | 0.00231     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.12        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00756    |
# |    reward               | -0.57513463 |
# |    std                  | 1           |
# |    value_loss           | 4.91        |
# -----------------------------------------
# day: 1949, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 690475.42
# total_reward: -309524.58
# total_cost: 848894.66
# total_trades: 7836
# Sharpe: -0.249
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 347        |
# |    iterations           | 4          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00440628 |
# |    clip_fraction        | 0.0469     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.11      |
# |    explained_variance   | 0.00247    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.09       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00283   |
# |    reward               | -1.0407772 |
# |    std                  | 1          |
# |    value_loss           | 4.51       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007462138 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | -0.000516   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.4         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00545    |
# |    reward               | -1.10337    |
# |    std                  | 1           |
# |    value_loss           | 4.43        |
# -----------------------------------------
# ======PPO Validation from:  2017-10-02 to  2018-01-02
# PPO Sharpe Ratio:  0.05183476833835954
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_126_15
# ======DDPG Validation from:  2017-10-02 to  2018-01-02
# ======Best Model Retraining from:  2010-01-01 to  2018-01-02
# ======Trading from:  2018-01-02 to  2018-04-04
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2018-01-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_189_14
# ======A2C Validation from:  2018-01-02 to  2018-04-04
# A2C Sharpe Ratio:  -0.14469533095305093
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_189_14
# -----------------------------------
# | time/              |            |
# |    fps             | 388        |
# |    iterations      | 1          |
# |    time_elapsed    | 5          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.15882486 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.007181092  |
# |    clip_fraction        | 0.081        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | -0.0347      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.75         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00617     |
# |    reward               | -0.018784365 |
# |    std                  | 1            |
# |    value_loss           | 3.54         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 349        |
# |    iterations           | 3          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00811916 |
# |    clip_fraction        | 0.0566     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.1       |
# |    explained_variance   | 0.00106    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.15       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0061    |
# |    reward               | -3.5974412 |
# |    std                  | 1          |
# |    value_loss           | 2.94       |
# ----------------------------------------
# day: 2012, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 746401.98
# total_reward: -253598.02
# total_cost: 864791.81
# total_trades: 7913
# Sharpe: -0.172
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010489683 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | -0.000844   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.46        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00914    |
# |    reward               | 1.7943171   |
# |    std                  | 1           |
# |    value_loss           | 4.15        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 5            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0063982448 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.11        |
# |    explained_variance   | 0.0141       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.87         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00414     |
# |    reward               | -0.055725154 |
# |    std                  | 1            |
# |    value_loss           | 3.84         |
# ------------------------------------------
# ======PPO Validation from:  2018-01-02 to  2018-04-04
# PPO Sharpe Ratio:  -0.1032025599064176
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_189_14
# ======DDPG Validation from:  2018-01-02 to  2018-04-04
# ======Best Model Retraining from:  2010-01-01 to  2018-04-04
# ======Trading from:  2018-04-04 to  2018-07-03
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2018-04-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_252_14
# ======A2C Validation from:  2018-04-04 to  2018-07-03
# A2C Sharpe Ratio:  -0.04682951189383126
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_252_14
# ------------------------------------
# | time/              |             |
# |    fps             | 379         |
# |    iterations      | 1           |
# |    time_elapsed    | 5           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.05812367 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007086099 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | -0.132      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.47        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00447    |
# |    reward               | 0.97556406  |
# |    std                  | 1           |
# |    value_loss           | 3.74        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 343        |
# |    iterations           | 3          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00578398 |
# |    clip_fraction        | 0.0585     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.09      |
# |    explained_variance   | 0.000728   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.52       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00592   |
# |    reward               | 0.43038142 |
# |    std                  | 0.998      |
# |    value_loss           | 5.65       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073440857 |
# |    clip_fraction        | 0.0646       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.1         |
# |    explained_variance   | -0.00391     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.03         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0067      |
# |    reward               | 0.37231934   |
# |    std                  | 1            |
# |    value_loss           | 4.47         |
# ------------------------------------------
# day: 2075, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 874668.34
# total_reward: -125331.66
# total_cost: 1022744.89
# total_trades: 8204
# Sharpe: -0.040
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 5            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0048733475 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.12        |
# |    explained_variance   | -0.00249     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.06         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00237     |
# |    reward               | 0.16843995   |
# |    std                  | 1.01         |
# |    value_loss           | 4.7          |
# ------------------------------------------
# ======PPO Validation from:  2018-04-04 to  2018-07-03
# PPO Sharpe Ratio:  -0.15049212981810023
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_252_14
# ======DDPG Validation from:  2018-04-04 to  2018-07-03
# ======Best Model Retraining from:  2010-01-01 to  2018-07-03
# ======Trading from:  2018-07-03 to  2018-10-02
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2018-07-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_315_14
# ======A2C Validation from:  2018-07-03 to  2018-10-02
# A2C Sharpe Ratio:  0.247816594700968
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_315_14
# -------------------------------------
# | time/              |              |
# |    fps             | 382          |
# |    iterations      | 1            |
# |    time_elapsed    | 5            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.063031554 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 359          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0053747753 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.11        |
# |    explained_variance   | -0.0192      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.92         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00349     |
# |    reward               | 0.09085622   |
# |    std                  | 1            |
# |    value_loss           | 3.53         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 350          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0065481057 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.11        |
# |    explained_variance   | -0.00709     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.79         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0042      |
# |    reward               | 0.10465749   |
# |    std                  | 1            |
# |    value_loss           | 3.48         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009138762 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.12       |
# |    explained_variance   | -0.00335    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.9         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00902    |
# |    reward               | -0.15116616 |
# |    std                  | 1.01        |
# |    value_loss           | 4.03        |
# -----------------------------------------
# day: 2138, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 684585.68
# total_reward: -315414.32
# total_cost: 1003493.94
# total_trades: 8308
# Sharpe: -0.244
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006772792 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | -0.00704    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.66        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00453    |
# |    reward               | 1.1065105   |
# |    std                  | 1.01        |
# |    value_loss           | 3.47        |
# -----------------------------------------
# ======PPO Validation from:  2018-07-03 to  2018-10-02
# PPO Sharpe Ratio:  0.024277000241903476
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_315_14
# ======DDPG Validation from:  2018-07-03 to  2018-10-02
# ======Best Model Retraining from:  2010-01-01 to  2018-10-02
# ======Trading from:  2018-10-02 to  2019-01-03
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2018-10-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_378_14
# ======A2C Validation from:  2018-10-02 to  2019-01-03
# A2C Sharpe Ratio:  -0.3746789990573205
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_378_14
# -------------------------------------
# | time/              |              |
# |    fps             | 400          |
# |    iterations      | 1            |
# |    time_elapsed    | 5            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.057780646 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006218124 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | -0.0122     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.02        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00524    |
# |    reward               | 0.13350879  |
# |    std                  | 1           |
# |    value_loss           | 3.81        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.007267044  |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.12        |
# |    explained_variance   | 0.00197      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.02         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00333     |
# |    reward               | -0.021227969 |
# |    std                  | 1.01         |
# |    value_loss           | 4.13         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0065312916 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.13        |
# |    explained_variance   | 0.0129       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.52         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00305     |
# |    reward               | -0.042617522 |
# |    std                  | 1.01         |
# |    value_loss           | 3.37         |
# ------------------------------------------
# day: 2201, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 564876.06
# total_reward: -435123.94
# total_cost: 898520.16
# total_trades: 8554
# Sharpe: -0.390
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 5           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005288464 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.0198      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.01        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00678    |
# |    reward               | 0.27407795  |
# |    std                  | 1.01        |
# |    value_loss           | 3.35        |
# -----------------------------------------
# ======PPO Validation from:  2018-10-02 to  2019-01-03
# PPO Sharpe Ratio:  -0.3968277933504345
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_378_14
# ======DDPG Validation from:  2018-10-02 to  2019-01-03
# ======Best Model Retraining from:  2010-01-01 to  2019-01-03
# ======Trading from:  2019-01-03 to  2019-04-04
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2019-01-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_441_14
# ======A2C Validation from:  2019-01-03 to  2019-04-04
# A2C Sharpe Ratio:  0.3061664520966289
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_441_14
# -------------------------------------
# | time/              |              |
# |    fps             | 365          |
# |    iterations      | 1            |
# |    time_elapsed    | 5            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.055287886 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008519712 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | -0.248      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.67        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00255    |
# |    reward               | -0.47437584 |
# |    std                  | 0.993       |
# |    value_loss           | 3.52        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0066179973 |
# |    clip_fraction        | 0.0751       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.06        |
# |    explained_variance   | 0.0213       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.35         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00847     |
# |    reward               | 0.39756486   |
# |    std                  | 0.993        |
# |    value_loss           | 3.83         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0054429644 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.06        |
# |    explained_variance   | 0.0344       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.42         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0032      |
# |    reward               | -0.46407115  |
# |    std                  | 0.991        |
# |    value_loss           | 3.87         |
# ------------------------------------------
# day: 2264, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 536865.58
# total_reward: -463134.42
# total_cost: 930886.49
# total_trades: 8668
# Sharpe: -0.391
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 5            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0055543184 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.06        |
# |    explained_variance   | -0.00504     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.93         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00595     |
# |    reward               | -0.02525553  |
# |    std                  | 0.999        |
# |    value_loss           | 4.1          |
# ------------------------------------------
# ======PPO Validation from:  2019-01-03 to  2019-04-04
# PPO Sharpe Ratio:  0.278745100025113
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_441_14
# ======DDPG Validation from:  2019-01-03 to  2019-04-04
# ======Best Model Retraining from:  2010-01-01 to  2019-04-04
# ======Trading from:  2019-04-04 to  2019-07-05
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2019-04-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_504_14
# ======A2C Validation from:  2019-04-04 to  2019-07-05
# A2C Sharpe Ratio:  -0.08194696504789876
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_504_14
# ----------------------------------
# | time/              |           |
# |    fps             | 415       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.0947301 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007883659 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | -0.0167     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.36        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00426    |
# |    reward               | 0.2136994   |
# |    std                  | 0.999       |
# |    value_loss           | 3.69        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0065838397 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.1         |
# |    explained_variance   | 0.0257       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.27         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00499     |
# |    reward               | 0.6271342    |
# |    std                  | 1            |
# |    value_loss           | 4.48         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0072371643 |
# |    clip_fraction        | 0.0929       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.12        |
# |    explained_variance   | 0.000309     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.02         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00547     |
# |    reward               | 1.8477765    |
# |    std                  | 1.01         |
# |    value_loss           | 4.12         |
# ------------------------------------------
# day: 2327, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 771993.35
# total_reward: -228006.65
# total_cost: 1136259.95
# total_trades: 9121
# Sharpe: -0.114
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 5           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008180012 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.14       |
# |    explained_variance   | 0.00887     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.65        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00468    |
# |    reward               | 0.053584706 |
# |    std                  | 1.01        |
# |    value_loss           | 3.9         |
# -----------------------------------------
# ======PPO Validation from:  2019-04-04 to  2019-07-05
# PPO Sharpe Ratio:  -0.04051363372001805
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_504_14
# ======DDPG Validation from:  2019-04-04 to  2019-07-05
# ======Best Model Retraining from:  2010-01-01 to  2019-07-05
# ======Trading from:  2019-07-05 to  2019-10-03
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2019-07-05
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_567_14
# ======A2C Validation from:  2019-07-05 to  2019-10-03
# A2C Sharpe Ratio:  -0.33533864543442177
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_567_14
# -----------------------------------
# | time/              |            |
# |    fps             | 360        |
# |    iterations      | 1          |
# |    time_elapsed    | 5          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.18067074 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008280425 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | -0.0445     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.1         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00829    |
# |    reward               | -0.93980813 |
# |    std                  | 0.997       |
# |    value_loss           | 3.61        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009453046 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | 0.0337      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.61        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00758    |
# |    reward               | 0.29964876  |
# |    std                  | 0.999       |
# |    value_loss           | 4.02        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 4            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0062499894 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0.0347       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.18         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00202     |
# |    reward               | 0.101250805  |
# |    std                  | 0.999        |
# |    value_loss           | 3.07         |
# ------------------------------------------
# day: 2390, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 684430.17
# total_reward: -315569.83
# total_cost: 1032049.85
# total_trades: 9433
# Sharpe: -0.199
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009213364 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | 0.0329      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.82        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00551    |
# |    reward               | 0.12264505  |
# |    std                  | 1           |
# |    value_loss           | 3.69        |
# -----------------------------------------
# ======PPO Validation from:  2019-07-05 to  2019-10-03
# PPO Sharpe Ratio:  -0.3239428445750507
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_567_14
# ======DDPG Validation from:  2019-07-05 to  2019-10-03
# ======Best Model Retraining from:  2010-01-01 to  2019-10-03
# ======Trading from:  2019-10-03 to  2020-01-03
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2019-10-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_630_14
# ======A2C Validation from:  2019-10-03 to  2020-01-03
# A2C Sharpe Ratio:  0.3008180202674233
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_630_14
# -------------------------------------
# | time/              |              |
# |    fps             | 355          |
# |    iterations      | 1            |
# |    time_elapsed    | 5            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.030708924 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008700814 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | -0.0537     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.73        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00739    |
# |    reward               | -0.20373642 |
# |    std                  | 0.996       |
# |    value_loss           | 3.18        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008006441 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.06       |
# |    explained_variance   | -0.000204   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.02        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00698    |
# |    reward               | -0.55097216 |
# |    std                  | 0.989       |
# |    value_loss           | 3.73        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007548823 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.04       |
# |    explained_variance   | 0.000241    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.88        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00667    |
# |    reward               | 0.18449996  |
# |    std                  | 0.988       |
# |    value_loss           | 4.21        |
# -----------------------------------------
# day: 2453, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 564207.63
# total_reward: -435792.37
# total_cost: 972565.78
# total_trades: 9424
# Sharpe: -0.326
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 5            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0064953566 |
# |    clip_fraction        | 0.0829       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.03        |
# |    explained_variance   | 0.00425      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.74         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00709     |
# |    reward               | -1.465842    |
# |    std                  | 0.988        |
# |    value_loss           | 3.94         |
# ------------------------------------------
# ======PPO Validation from:  2019-10-03 to  2020-01-03
# PPO Sharpe Ratio:  0.4064880806538781
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_630_14
# ======DDPG Validation from:  2019-10-03 to  2020-01-03
# ======Best Model Retraining from:  2010-01-01 to  2020-01-03
# ======Trading from:  2020-01-03 to  2020-04-03
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2020-01-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_693_14
# ======A2C Validation from:  2020-01-03 to  2020-04-03
# A2C Sharpe Ratio:  -0.13870897076986866
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_693_14
# -----------------------------------
# | time/              |            |
# |    fps             | 365        |
# |    iterations      | 1          |
# |    time_elapsed    | 5          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.13716722 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008431445 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | -0.0594     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.56        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00748    |
# |    reward               | 1.2623396   |
# |    std                  | 1           |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006412848 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | 0.0148      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.09        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00687    |
# |    reward               | -0.09874811 |
# |    std                  | 1           |
# |    value_loss           | 4.26        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 334        |
# |    iterations           | 4          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00525314 |
# |    clip_fraction        | 0.0519     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.11      |
# |    explained_variance   | 0.00724    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.73       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00352   |
# |    reward               | 0.07382561 |
# |    std                  | 1          |
# |    value_loss           | 3.26       |
# ----------------------------------------
# day: 2516, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 709167.75
# total_reward: -290832.25
# total_cost: 1128461.82
# total_trades: 9978
# Sharpe: -0.162
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 5           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007028457 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | -0.00574    |
# |    learning_rate        | 0.00025     |
# ...
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005933404 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | -0.0101     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.83        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00716    |
# |    reward               | 0.66082937  |
# |    std                  | 1           |
# |    value_loss           | 3.63        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 5           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007542544 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.00894     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.18        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00482    |
# |    reward               | -0.19764304 |
# |    std                  | 1.01        |
# |    value_loss           | 2.99        |
# -----------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.2383786791630569
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_1134_13
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2022-01-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_1197_13
# ======A2C Validation from:  2022-01-03 to  2022-04-04
# A2C Sharpe Ratio:  -0.31987218549695806
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_1197_13
# -----------------------------------
# | time/              |            |
# |    fps             | 354        |
# |    iterations      | 1          |
# |    time_elapsed    | 5          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.22310184 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0066416394 |
# |    clip_fraction        | 0.0883       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.11        |
# |    explained_variance   | -0.00657     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.54         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00649     |
# |    reward               | -0.8373593   |
# |    std                  | 1.01         |
# |    value_loss           | 3.21         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007660066 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.0152      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.91        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00636    |
# |    reward               | -0.67109096 |
# |    std                  | 1.01        |
# |    value_loss           | 3.96        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 4           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.00915336  |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.12       |
# |    explained_variance   | 0.0257      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.63        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00649    |
# |    reward               | -0.13547966 |
# |    std                  | 1.01        |
# |    value_loss           | 2.58        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 5            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0059141647 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.13        |
# |    explained_variance   | 0.017        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.92         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00396     |
# |    reward               | 0.05989658   |
# |    std                  | 1.01         |
# |    value_loss           | 3.1          |
# ------------------------------------------
# ======PPO Validation from:  2022-01-03 to  2022-04-04
# PPO Sharpe Ratio:  -0.11867060692300493
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_1197_13
# ======DDPG Validation from:  2022-01-03 to  2022-04-04
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2022-04-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_1260_13
# ======A2C Validation from:  2022-04-04 to  2022-07-06
# A2C Sharpe Ratio:  -0.3649628991277166
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_1260_13
# -------------------------------------
# | time/              |              |
# |    fps             | 382          |
# |    iterations      | 1            |
# |    time_elapsed    | 5            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.072747014 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009444514 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | -0.0213     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.87        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00509    |
# |    reward               | -0.08567593 |
# |    std                  | 0.996       |
# |    value_loss           | 3.64        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0065431604 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | -0.00116     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.84         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00588     |
# |    reward               | -0.59946764  |
# |    std                  | 1            |
# |    value_loss           | 4.36         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 4           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006071949 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | 0.0239      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.692       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00508    |
# |    reward               | -0.21654609 |
# |    std                  | 1.01        |
# |    value_loss           | 1.47        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006661131 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.0111      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.22        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00492    |
# |    reward               | -0.42920372 |
# |    std                  | 1.01        |
# |    value_loss           | 3.8         |
# -----------------------------------------
# ======PPO Validation from:  2022-04-04 to  2022-07-06
# PPO Sharpe Ratio:  -0.33796059032389636
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_1260_13
# ======DDPG Validation from:  2022-04-04 to  2022-07-06
# ======Best Model Retraining from:  2010-01-01 to  2022-07-06
# ======Trading from:  2022-07-06 to  2022-10-04
# ============================================
# turbulence_threshold:  27.90730730085542
# ======Model training from:  2010-01-01 to  2022-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_1323_13
# ======A2C Validation from:  2022-07-06 to  2022-10-04
# A2C Sharpe Ratio:  -0.22635576345571007
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_1323_13
# -------------------------------------
# | time/              |              |
# |    fps             | 345          |
# |    iterations      | 1            |
# |    time_elapsed    | 5            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.012468936 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008374632 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | 0.0016      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.04        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00736    |
# |    reward               | 1.8454316   |
# |    std                  | 1           |
# |    value_loss           | 3.54        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005433178 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | -0.00886    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.86        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00691    |
# |    reward               | 0.7160154   |
# |    std                  | 1           |
# |    value_loss           | 5.74        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 4            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0068197018 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0.0245       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.942        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00373     |
# |    reward               | 0.3429557    |
# |    std                  | 0.999        |
# |    value_loss           | 1.99         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007028989 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | -0.0164     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.08        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00549    |
# |    reward               | 0.2837612   |
# |    std                  | 1           |
# |    value_loss           | 3.85        |
# -----------------------------------------
# ======PPO Validation from:  2022-07-06 to  2022-10-04
# PPO Sharpe Ratio:  -0.18142444298138546
# ======DDPG Training========
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_1323_13
# ======DDPG Validation from:  2022-07-06 to  2022-10-04
# ======Best Model Retraining from:  2010-01-01 to  2022-10-04
# ======Trading from:  2022-10-04 to  2023-01-04
# Ensemble Strategy took:  10.93863485654195  minutes

# %%
df_summary
# Out:
#     Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0    126  2017-10-02  2018-01-02       DDPG  -0.052303  -0.025698    0.389041
# 1    189  2018-01-02  2018-04-04        A2C  -0.036335   -0.10057   -0.071608
# 2    252  2018-04-04  2018-07-03       DDPG   0.031087   0.009445    0.074493
# 3    315  2018-07-03  2018-10-02        A2C   0.477037   0.036381    0.414955
# 4    378  2018-10-02  2019-01-03        PPO  -0.372531  -0.312252   -0.363208
# 5    441  2019-01-03  2019-04-04       DDPG    0.57734   0.413581    0.654107
# 6    504  2019-04-04  2019-07-05        A2C   0.162343   0.023609    0.140098
# 7    567  2019-07-05  2019-10-03        A2C  -0.131658  -0.386474   -0.169408
# 8    630  2019-10-03  2020-01-03        A2C   0.733037   0.513231    0.635318
# 9    693  2020-01-03  2020-04-03        A2C  -0.153105  -0.279637   -0.165596
# 10   756  2020-04-03  2020-07-06        A2C   0.498224   0.228505     0.33556
# 11   819  2020-07-06  2020-10-02        PPO   0.211791   0.301456    0.204343
# 12   882  2020-10-02  2021-01-04        PPO   0.209603   0.421804    0.378399
# 13   945  2021-01-04  2021-04-06       DDPG   0.339903   0.206966    0.398965
# 14  1008  2021-04-06  2021-07-06        A2C   0.242992   0.140145         0.0
# 15  1071  2021-07-06  2021-10-04        A2C  -0.047295   -0.18386   -0.063952
# 16  1134  2021-10-04  2022-01-03        A2C   0.338724  -0.031373     0.17489
# 17  1197  2022-01-03  2022-04-04        A2C  -0.172843  -0.267342   -0.231169
# 18  1260  2022-04-04  2022-07-06       DDPG  -0.325065  -0.381789   -0.272436
# 19  1323  2022-07-06  2022-10-04        A2C  -0.080444  -0.372254   -0.102126

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = pd.concat([df_account_value,temp],ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.49714334759512036

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2018-01-02           NaN  2018-01-02
# 1   1.003208e+06  2018-01-03      0.003208  2018-01-03
# 2   1.008688e+06  2018-01-04      0.005463  2018-01-04
# 3   1.014446e+06  2018-01-05      0.005708  2018-01-05
# 4   1.015302e+06  2018-01-08      0.000844  2018-01-08

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.075913
# Cumulative returns     0.441734
# Annual volatility      0.179854
# Sharpe ratio           0.497143
# Calmar ratio           0.306632
# Stability              0.732589
# Max drawdown          -0.247569
# Omega ratio            1.092364
# Sortino ratio          0.701433
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.930363
# Daily value at risk   -0.022305
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (1259, 8)
# Annual return          0.059583
# Cumulative returns     0.335290
# Annual volatility      0.217954
# Sharpe ratio           0.375375
# Calmar ratio           0.160661
# Stability              0.685042
# Max drawdown          -0.370862
# Omega ratio            1.077914
# Sortino ratio          0.516270
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.893140
# Daily value at risk   -0.027135
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv('df_account_value.csv')
# Out:
# df_dji:              date           dji
# 0     2018-01-02  1.000000e+06
# 1     2018-01-03  1.003975e+06
# 2     2018-01-04  1.010116e+06
# 3     2018-01-05  1.019008e+06
# 4     2018-01-08  1.018490e+06
# ...          ...           ...
# 1255  2022-12-27  1.339089e+06
# 1256  2022-12-28  1.324351e+06
# 1257  2022-12-29  1.338253e+06
# 1258  2022-12-30  1.335290e+06
# 1259  2023-01-03           NaN
#
# [1260 rows x 2 columns]
# df_dji:                       dji
# date
# 2018-01-02  1.000000e+06
# 2018-01-03  1.003975e+06
# 2018-01-04  1.010116e+06
# 2018-01-05  1.019008e+06
# 2018-01-08  1.018490e+06
# ...                  ...
# 2022-12-27  1.339089e+06
# 2022-12-28  1.324351e+06
# 2022-12-29  1.338253e+06
# 2022-12-30  1.335290e+06
# 2023-01-03           NaN
#
# [1260 rows x 1 columns]

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
# print("==============Compare to DJIA===========")
# %matplotlib inline
# # S&P 500: ^GSPC
# # Dow Jones Index: ^DJI
# # NASDAQ 100: ^NDX
# backtest_plot(df_account_value, 
#               baseline_ticker = '^DJI', 
#               baseline_start = df_account_value.loc[0,'date'],
#               baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date': df_account_value['date'], 'ensemble': df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')

print("df_result_ensemble.columns: ", df_result_ensemble.columns)

# df_result_ensemble.drop(df_result_ensemble.columns[0], axis = 1)
print("df_trade_date: ", df_trade_date)
# df_result_ensemble['date'] = df_trade_date['datadate']
# df_result_ensemble['account_value'] = df_account_value['account_value']
df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble: ", df_result_ensemble)
print("==============Compare to DJIA===========")
result = pd.DataFrame()
# result = pd.merge(result, df_result_ensemble, left_index=True, right_index=True)
# result = pd.merge(result, df_dji, left_index=True, right_index=True)
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
print("result: ", result)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date:          datadate
# 0     2017-10-02
# 1     2017-10-03
# 2     2017-10-04
# 3     2017-10-05
# 4     2017-10-06
# ...          ...
# 1356  2023-02-22
# 1357  2023-02-23
# 1358  2023-02-24
# 1359  2023-02-27
# 1360  2023-02-28
#
# [1361 rows x 1 columns]
# df_result_ensemble:                  ensemble
# date
# 2018-01-02  1.000000e+06
# 2018-01-03  1.003208e+06
# 2018-01-04  1.008688e+06
# 2018-01-05  1.014446e+06
# 2018-01-08  1.015302e+06
# ...                  ...
# 2022-12-27  1.443661e+06
# 2022-12-28  1.426307e+06
# 2022-12-29  1.451212e+06
# 2022-12-30  1.447525e+06
# 2023-01-03  1.441734e+06
#
# [1260 rows x 1 columns]
# ==============Compare to DJIA===========
# result:                  ensemble           dji
# date
# 2018-01-02  1.000000e+06  1.000000e+06
# 2018-01-03  1.003208e+06  1.003975e+06
# 2018-01-04  1.008688e+06  1.010116e+06
# 2018-01-05  1.014446e+06  1.019008e+06
# 2018-01-08  1.015302e+06  1.018490e+06
# ...                  ...           ...
# 2022-12-27  1.443661e+06  1.339089e+06
# 2022-12-28  1.426307e+06  1.324351e+06
# 2022-12-29  1.451212e+06  1.338253e+06
# 2022-12-30  1.447525e+06  1.335290e+06
# 2023-01-03  1.441734e+06           NaN
#
# [1260 rows x 2 columns]
